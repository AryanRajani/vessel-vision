# %% [markdown]
# I couldn't find a notebook using the new mmdet version 3.0.0, so I made one myself. Please let me know if there are any mistakes!
#
# the annotation josn file is from [this great notebook](https://www.kaggle.com/code/ammarnassanalhajali/hubmap-2023-k-fold-cv-coco-dataset-generator).
#
# inference notebook is [here](https://www.kaggle.com/code/andtaichi/hubmap-mmdet-ver3-0-0-infer/notebook).

# %%
# !pip install -qqq /kaggle/input/mmdet3-wheels-ando/addict-2.4.0-py3-none-any.whl
# !pip install -qqq /kaggle/input/mmdet3-wheels-ando/mmengine-0.7.3-py3-none-any.whl
# !pip install -qqq /kaggle/input/mmdet3-wheels-ando/mmcv-2.0.0-cp310-cp310-linux_x86_64.whl
# !pip install -qqq /kaggle/input/pycocotools-206/wheels/pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl
# !pip install -qqq /kaggle/input/mmdet3-wheels-ando/terminaltables-3.1.10-py2.py3-none-any.whl
# !pip install -qqq /kaggle/input/mmdet3-wheels-ando/mmdet-3.0.0-py3-none-any.whl

# %%
import mmdet, mmcv
print(mmdet.__version__)
print(mmcv.__version__)
# Out:
# 3.0.0
# 2.0.0

# %% [markdown]
# ## Make config file

# %%
# %mkdir /kaggle/working/configs/

# %%
# %%writefile /kaggle/working/configs/custom_config.py

model = dict(
    type='MaskRCNN',
    data_preprocessor=dict(
        type='DetDataPreprocessor',
        mean=[123.675, 116.28, 103.53],
        std=[58.395, 57.12, 57.375],
        bgr_to_rgb=True,
        pad_mask=True,
        pad_size_divisor=32),
    backbone=dict(
        type='RegNet',
        arch='regnetx_12gf',
        out_indices=(0, 1, 2, 3),
        frozen_stages=1,
        norm_cfg=dict(type='BN', requires_grad=True),
        norm_eval=True,
        style='pytorch',
        init_cfg=dict(
            type='Pretrained', checkpoint='open-mmlab://regnetx_12gf')),
    neck=dict(
        type='FPN',
        in_channels=[224, 448, 896, 2240],
        out_channels=256,
        num_outs=5),
    rpn_head=dict(
        type='RPNHead',
        in_channels=256,
        feat_channels=256,
        anchor_generator=dict(
            type='AnchorGenerator',
            scales=[8],
            ratios=[0.5, 1.0, 2.0],
            strides=[4, 8, 16, 32, 64]),
        bbox_coder=dict(
            type='DeltaXYWHBBoxCoder',
            target_means=[0.0, 0.0, 0.0, 0.0],
            target_stds=[1.0, 1.0, 1.0, 1.0]),
        loss_cls=dict(
            type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
        loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
    roi_head=dict(
        type='StandardRoIHead',
        bbox_roi_extractor=dict(
            type='SingleRoIExtractor',
            roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
            out_channels=256,
            featmap_strides=[4, 8, 16, 32]),
        bbox_head=dict(
            type='Shared2FCBBoxHead',
            in_channels=256,
            fc_out_channels=1024,
            roi_feat_size=7,
            num_classes=2,
            bbox_coder=dict(
                type='DeltaXYWHBBoxCoder',
                target_means=[0.0, 0.0, 0.0, 0.0],
                target_stds=[0.1, 0.1, 0.2, 0.2]),
            reg_class_agnostic=False,
            loss_cls=dict(
                type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
            loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
        mask_roi_extractor=dict(
            type='SingleRoIExtractor',
            roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
            out_channels=256,
            featmap_strides=[4, 8, 16, 32]),
        mask_head=dict(
            type='FCNMaskHead',
            num_convs=4,
            in_channels=256,
            conv_out_channels=256,
            num_classes=2,
            loss_mask=dict(
                type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
    train_cfg=dict(
        rpn=dict(
            assigner=dict(
                type='MaxIoUAssigner',
                pos_iou_thr=0.7,
                neg_iou_thr=0.3,
                min_pos_iou=0.3,
                match_low_quality=True,
                ignore_iof_thr=-1),
            sampler=dict(
                type='RandomSampler',
                num=256,
                pos_fraction=0.5,
                neg_pos_ub=-1,
                add_gt_as_proposals=False),
            allowed_border=-1,
            pos_weight=-1,
            debug=False),
        rpn_proposal=dict(
            nms_across_levels=False,
            nms_pre=2000,
            nms_post=1000,
            max_per_img=1000,
            nms=dict(type='nms', iou_threshold=0.5),
            min_bbox_size=0),
        rcnn=dict(
            assigner=dict(
                type='MaxIoUAssigner',
                pos_iou_thr=0.5,
                neg_iou_thr=0.5,
                min_pos_iou=0.5,
                match_low_quality=False,
                ignore_iof_thr=-1),
            sampler=dict(
                type='RandomSampler',
                num=512,
                pos_fraction=0.25,
                neg_pos_ub=-1,
                add_gt_as_proposals=True),
            mask_size=28,
            pos_weight=-1,
            debug=False)),
    test_cfg=dict(
        rpn=dict(
            nms_across_levels=False,
            nms_pre=1000,
            nms_post=1000,
            max_per_img=500,
            nms=dict(type='nms', iou_threshold=0.7),
            min_bbox_size=0),
        rcnn=dict(
            score_thr=0.01,
            nms=dict(type='nms', iou_thr=0.5),
            max_per_img=50,
            mask_thr_binary=0.5)))
dataset_type = 'CocoDataset'
data_root = ''
backend_args = None
metainfo=dict(classes=('blood_vessel', 'glomerulus'), palette=[(255, 0, 0), (0, 255, 0)])

train_dataloader = dict(
    batch_size=2,
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    batch_sampler=dict(type='AspectRatioBatchSampler'),
    dataset=dict(
        type='CocoDataset',
        metainfo=dict(classes=('blood_vessel', 'glomerulus'), palette=[(255, 0, 0), (0, 255, 0)]),
        data_root='',
        ann_file='/kaggle/input/coco-hubmap-fold-1/coco_annotations_train_all_fold10.json',
        data_prefix=dict(
            img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
        filter_cfg=dict(filter_empty_gt=True, min_size=32),
        pipeline=[
            dict(type='LoadImageFromFile', backend_args=None),
            dict(
                type='LoadAnnotations',
                with_bbox=True,
                with_mask=True,
                poly2mask=True),
            dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
            dict(
                type='RandomFlip',
                direction=['horizontal', 'vertical'],
                prob=0.5),
            dict(type='PackDetInputs')
        ],
        backend_args=None))
val_dataloader = dict(
    batch_size=1,
    num_workers=2,
    persistent_workers=True,
    drop_last=False,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='CocoDataset',
        metainfo=dict(classes=('blood_vessel', 'glomerulus'), palette=[(255, 0, 0), (0, 255, 0)]),
        data_root='',
        ann_file=
        '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
        data_prefix=dict(
            img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
        test_mode=True,
        pipeline=[
            dict(type='LoadImageFromFile', backend_args=None),
            dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
            dict(
                type='PackDetInputs',
                meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
                           'scale_factor'))
        ],
        backend_args=None))
test_dataloader = dict(
    batch_size=1,
    num_workers=2,
    persistent_workers=True,
    drop_last=False,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='CocoDataset',
        metainfo=dict(classes=('blood_vessel', 'glomerulus'), palette=[(255, 0, 0), (0, 255, 0)]),
        data_root='',
        ann_file=
        '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
        data_prefix=dict(
            img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
        test_mode=True,
        pipeline=[
            dict(type='LoadImageFromFile', backend_args=None),
            dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
            dict(
                type='PackDetInputs',
                meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
                           'scale_factor'))
        ],
        backend_args=None))
val_evaluator = dict(
    type='CocoMetric',
    ann_file=
    '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
    metric=['segm'],
    format_only=False,
    backend_args=None)
#     iou_thrs=[0.5]
test_evaluator = dict(
    type='CocoMetric',
    ann_file=
    '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
    metric=['segm'],
    format_only=False,
    backend_args=None)
#     iou_thrs=[0.5]
optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=dict(type='SGD', lr=0.02, momentum=0.91, weight_decay=0.00005),
    clip_grad=None)
param_scheduler = [
    dict(
        type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
    dict(
        type='MultiStepLR',
        by_epoch=True,
        begin=0,
        end=30,
        milestones=[13, 17, 21],
        gamma=0.2)
]
default_hooks = dict(
    timer=dict(type='IterTimerHook'),
    logger=dict(type='LoggerHook', interval=50),
    param_scheduler=dict(type='ParamSchedulerHook'),
    checkpoint=dict(
        type='CheckpointHook', interval=3, save_best='coco/segm_mAP'),
    sampler_seed=dict(type='DistSamplerSeedHook'),
    visualization=dict(type='DetVisualizationHook'))
custom_hooks = [
    dict(
        type='EarlyStoppingHook',
        monitor='coco/segm_mAP',
        rule='greater',
        min_delta=0.005,
        strict=False,
        check_finite=True,
        patience=15,
        stopping_threshold=None)
]
default_scope = 'mmdet'
env_cfg = dict(
    cudnn_benchmark=False,
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
    dist_cfg=dict(backend='nccl'))
vis_backends = [dict(type='LocalVisBackend')]
visualizer = dict(
    type='DetLocalVisualizer',
    vis_backends=[dict(type='LocalVisBackend')],
    name='visualizer')
log_config = dict(hooks=[
    dict(type='TextLoggerHook'),
    dict(
        type='MMDetWandbHook',
        init_kwargs=dict(project='mmdetection'),
        interval=10,
        log_checkpoint=True,
        log_checkpoint_metadata=True,
        num_eval_images=100,
        bbox_score_thr=0.25)
])
log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
log_level = 'INFO'
load_from = None
resume = False
train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=30, val_interval=1)
val_cfg = dict(type='ValLoop')
test_cfg = dict(type='TestLoop')
work_dir = '/kaggle/working/work_dir'
# Out:
# Writing /kaggle/working/configs/custom_config.py

# %%
from mmengine.config import Config
from mmengine.runner import Runner

from mmdet.utils import register_all_modules

cfg = Config.fromfile("/kaggle/working/configs/custom_config.py")

cfg.work_dir = "/kaggle/working/work_dir"
runner = Runner.from_cfg(cfg)
# Out:
# 07/29 18:32:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.10 | packaged by conda-forge | (main, Mar 24 2023, 20:08:06) [GCC 11.3.0]
#     CUDA available: True
#     numpy_random_seed: 83005302
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04) 11.3.0
#     PyTorch: 2.0.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 11.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_70,code=compute_70;-gencode;arch=compute_75,code=compute_75
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=1 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=range-loop-construct -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1
#     OpenCV: 4.7.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/29 18:32:36 - mmengine - INFO - Config:
# model = dict(
#     type='MaskRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_mask=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='RegNet',
#         arch='regnetx_12gf',
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(
#             type='Pretrained', checkpoint='open-mmlab://regnetx_12gf')),
#     neck=dict(
#         type='FPN',
#         in_channels=[224, 448, 896, 2240],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=2,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=2,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_across_levels=False,
#             nms_pre=2000,
#             nms_post=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.5),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             mask_size=28,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_across_levels=False,
#             nms_pre=1000,
#             nms_post=1000,
#             max_per_img=500,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.01,
#             nms=dict(type='nms', iou_thr=0.5),
#             max_per_img=50,
#             mask_thr_binary=0.5)))
# dataset_type = 'CocoDataset'
# data_root = ''
# backend_args = None
# metainfo = dict(
#     classes=('blood_vessel', 'glomerulus'), palette=[(255, 0, 0), (0, 255, 0)])
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(
#             classes=('blood_vessel', 'glomerulus'),
#             palette=[(255, 0, 0), (0, 255, 0)]),
#         data_root='',
#         ann_file=
#         '/kaggle/input/coco-hubmap-fold-1/coco_annotations_train_all_fold10.json',
#         data_prefix=dict(
#             img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 poly2mask=True),
#             dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
#             dict(
#                 type='RandomFlip',
#                 direction=['horizontal', 'vertical'],
#                 prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(
#             classes=('blood_vessel', 'glomerulus'),
#             palette=[(255, 0, 0), (0, 255, 0)]),
#         data_root='',
#         ann_file=
#         '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
#         data_prefix=dict(
#             img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(
#             classes=('blood_vessel', 'glomerulus'),
#             palette=[(255, 0, 0), (0, 255, 0)]),
#         data_root='',
#         ann_file=
#         '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
#         data_prefix=dict(
#             img='/kaggle/input/hubmap-hacking-the-human-vasculature/train/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
#     metric=['segm'],
#     format_only=False,
#     backend_args=None)
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/kaggle/input/coco-hubmap-fold-1/coco_annotations_valid_all_fold10.json',
#     metric=['segm'],
#     format_only=False,
#     backend_args=None)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.91, weight_decay=5e-05),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         by_epoch=True,
#         begin=0,
#         end=30,
#         milestones=[13, 17, 21],
#         gamma=0.2)
# ]
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=3, save_best='coco/segm_mAP'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# custom_hooks = [
#     dict(
#         type='EarlyStoppingHook',
#         monitor='coco/segm_mAP',
#         rule='greater',
#         min_delta=0.005,
#         strict=False,
#         check_finite=True,
#         patience=15,
#         stopping_threshold=None)
# ]
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_config = dict(hooks=[
#     dict(type='TextLoggerHook'),
#     dict(
#         type='MMDetWandbHook',
#         init_kwargs=dict(project='mmdetection'),
#         interval=10,
#         log_checkpoint=True,
#         log_checkpoint_metadata=True,
#         num_eval_images=100,
#         bbox_score_thr=0.25)
# ])
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=30, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# work_dir = '/kaggle/working/work_dir'
#
# 07/29 18:32:46 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/29 18:32:46 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
runner.train()
# Out:
# loading annotations into memory...
# Done (t=0.86s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 07/29 18:32:53 - mmengine - INFO - load model from: open-mmlab://regnetx_12gf
# 07/29 18:32:53 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://regnetx_12gf
# Downloading: "https://download.openmmlab.com/pretrain/third_party/regnetx_12gf-4c2a3350.pth" to /root/.cache/torch/hub/checkpoints/regnetx_12gf-4c2a3350.pth
# 07/29 18:33:09 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 07/29 18:33:09 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 07/29 18:33:09 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 07/29 18:33:09 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/work_dir.
# 07/29 18:34:10 - mmengine - INFO - Epoch(train)  [1][ 50/731]  lr: 1.9820e-03  eta: 7:26:44  time: 1.2251  data_time: 0.0614  memory: 6380  loss: 1.8463  loss_rpn_cls: 0.6391  loss_rpn_bbox: 0.0973  loss_cls: 0.2799  acc: 97.9492  loss_bbox: 0.0302  loss_mask: 0.7997
# 07/29 18:35:06 - mmengine - INFO - Epoch(train)  [1][100/731]  lr: 3.9840e-03  eta: 7:05:49  time: 1.1157  data_time: 0.0545  memory: 6381  loss: 1.2361  loss_rpn_cls: 0.3700  loss_rpn_bbox: 0.1032  loss_cls: 0.1648  acc: 95.8984  loss_bbox: 0.0736  loss_mask: 0.5245
# 07/29 18:36:02 - mmengine - INFO - Epoch(train)  [1][150/731]  lr: 5.9860e-03  eta: 6:59:59  time: 1.1303  data_time: 0.0638  memory: 6380  loss: 1.1861  loss_rpn_cls: 0.2713  loss_rpn_bbox: 0.1014  loss_cls: 0.1978  acc: 97.6562  loss_bbox: 0.1375  loss_mask: 0.4781
# 07/29 18:36:58 - mmengine - INFO - Epoch(train)  [1][200/731]  lr: 7.9880e-03  eta: 6:55:03  time: 1.1131  data_time: 0.0462  memory: 6381  loss: 1.0579  loss_rpn_cls: 0.1881  loss_rpn_bbox: 0.0909  loss_cls: 0.1835  acc: 95.4102  loss_bbox: 0.1455  loss_mask: 0.4499
# 07/29 18:37:54 - mmengine - INFO - Epoch(train)  [1][250/731]  lr: 9.9900e-03  eta: 6:52:10  time: 1.1193  data_time: 0.0509  memory: 6379  loss: 1.0867  loss_rpn_cls: 0.1650  loss_rpn_bbox: 0.1054  loss_cls: 0.2086  acc: 93.3594  loss_bbox: 0.1657  loss_mask: 0.4420
# 07/29 18:38:50 - mmengine - INFO - Epoch(train)  [1][300/731]  lr: 1.1992e-02  eta: 6:49:35  time: 1.1136  data_time: 0.0483  memory: 6382  loss: 1.0349  loss_rpn_cls: 0.1450  loss_rpn_bbox: 0.0990  loss_cls: 0.1861  acc: 95.1172  loss_bbox: 0.1809  loss_mask: 0.4240
# 07/29 18:39:46 - mmengine - INFO - Epoch(train)  [1][350/731]  lr: 1.3994e-02  eta: 6:48:05  time: 1.1255  data_time: 0.0547  memory: 6380  loss: 1.0229  loss_rpn_cls: 0.1525  loss_rpn_bbox: 0.1032  loss_cls: 0.1946  acc: 93.4570  loss_bbox: 0.1818  loss_mask: 0.3908
# 07/29 18:40:42 - mmengine - INFO - Epoch(train)  [1][400/731]  lr: 1.5996e-02  eta: 6:46:39  time: 1.1237  data_time: 0.0552  memory: 6379  loss: 1.0002  loss_rpn_cls: 0.1428  loss_rpn_bbox: 0.0929  loss_cls: 0.1864  acc: 92.9688  loss_bbox: 0.1854  loss_mask: 0.3927
# 07/29 18:41:39 - mmengine - INFO - Epoch(train)  [1][450/731]  lr: 1.7998e-02  eta: 6:45:58  time: 1.1397  data_time: 0.0646  memory: 6380  loss: 1.0188  loss_rpn_cls: 0.1386  loss_rpn_bbox: 0.1067  loss_cls: 0.1957  acc: 93.3594  loss_bbox: 0.1969  loss_mask: 0.3809
# 07/29 18:42:36 - mmengine - INFO - Epoch(train)  [1][500/731]  lr: 2.0000e-02  eta: 6:44:53  time: 1.1302  data_time: 0.0604  memory: 6480  loss: 1.0209  loss_rpn_cls: 0.1651  loss_rpn_bbox: 0.0973  loss_cls: 0.1934  acc: 93.0664  loss_bbox: 0.1664  loss_mask: 0.3988
# 07/29 18:43:31 - mmengine - INFO - Epoch(train)  [1][550/731]  lr: 2.0000e-02  eta: 6:43:23  time: 1.1164  data_time: 0.0495  memory: 6380  loss: 0.9703  loss_rpn_cls: 0.1373  loss_rpn_bbox: 0.0905  loss_cls: 0.1868  acc: 93.7500  loss_bbox: 0.1730  loss_mask: 0.3828
# 07/29 18:44:27 - mmengine - INFO - Epoch(train)  [1][600/731]  lr: 2.0000e-02  eta: 6:42:05  time: 1.1201  data_time: 0.0531  memory: 6395  loss: 0.8996  loss_rpn_cls: 0.1246  loss_rpn_bbox: 0.0901  loss_cls: 0.1636  acc: 93.9453  loss_bbox: 0.1601  loss_mask: 0.3613
# 07/29 18:45:23 - mmengine - INFO - Epoch(train)  [1][650/731]  lr: 2.0000e-02  eta: 6:40:45  time: 1.1166  data_time: 0.0502  memory: 6381  loss: 0.9543  loss_rpn_cls: 0.1288  loss_rpn_bbox: 0.0919  loss_cls: 0.1809  acc: 95.1172  loss_bbox: 0.1663  loss_mask: 0.3864
# 07/29 18:46:20 - mmengine - INFO - Epoch(train)  [1][700/731]  lr: 2.0000e-02  eta: 6:39:44  time: 1.1270  data_time: 0.0567  memory: 6382  loss: 0.9432  loss_rpn_cls: 0.1214  loss_rpn_bbox: 0.1003  loss_cls: 0.1795  acc: 95.0195  loss_bbox: 0.1703  loss_mask: 0.3717
# 07/29 18:46:54 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 18:47:02 - mmengine - INFO - Epoch(val)  [1][ 50/163]    eta: 0:00:17  time: 0.1527  data_time: 0.0050  memory: 6379
# 07/29 18:47:09 - mmengine - INFO - Epoch(val)  [1][100/163]    eta: 0:00:09  time: 0.1479  data_time: 0.0022  memory: 1005
# 07/29 18:47:17 - mmengine - INFO - Epoch(val)  [1][150/163]    eta: 0:00:01  time: 0.1529  data_time: 0.0026  memory: 1005
# 07/29 18:47:20 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=3.07s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.012
# 07/29 18:47:23 - mmengine - INFO - segm_mAP_copypaste: 0.047 0.149 0.013 0.052 0.052 0.013
# 07/29 18:47:23 - mmengine - INFO - Epoch(val) [1][163/163]    coco/segm_mAP: 0.0470  coco/segm_mAP_50: 0.1490  coco/segm_mAP_75: 0.0130  coco/segm_mAP_s: 0.0520  coco/segm_mAP_m: 0.0520  coco/segm_mAP_l: 0.0130  data_time: 0.0031  time: 0.1510
# 07/29 18:47:27 - mmengine - INFO - The best checkpoint with 0.0470 coco/segm_mAP at 1 epoch is saved to best_coco_segm_mAP_epoch_1.pth.
# 07/29 18:48:23 - mmengine - INFO - Epoch(train)  [2][ 50/731]  lr: 2.0000e-02  eta: 6:37:59  time: 1.1264  data_time: 0.0551  memory: 6478  loss: 0.8889  loss_rpn_cls: 0.0899  loss_rpn_bbox: 0.0858  loss_cls: 0.1731  acc: 92.8711  loss_bbox: 0.1919  loss_mask: 0.3482
# 07/29 18:49:19 - mmengine - INFO - Epoch(train)  [2][100/731]  lr: 2.0000e-02  eta: 6:36:47  time: 1.1166  data_time: 0.0490  memory: 6381  loss: 0.8958  loss_rpn_cls: 0.0909  loss_rpn_bbox: 0.0875  loss_cls: 0.1729  acc: 93.4570  loss_bbox: 0.1635  loss_mask: 0.3810
# 07/29 18:50:15 - mmengine - INFO - Epoch(train)  [2][150/731]  lr: 2.0000e-02  eta: 6:35:46  time: 1.1250  data_time: 0.0530  memory: 6437  loss: 0.9034  loss_rpn_cls: 0.0952  loss_rpn_bbox: 0.0876  loss_cls: 0.1733  acc: 94.0430  loss_bbox: 0.1864  loss_mask: 0.3609
# 07/29 18:51:12 - mmengine - INFO - Epoch(train)  [2][200/731]  lr: 2.0000e-02  eta: 6:34:52  time: 1.1299  data_time: 0.0581  memory: 6382  loss: 0.8667  loss_rpn_cls: 0.0895  loss_rpn_bbox: 0.0825  loss_cls: 0.1683  acc: 95.2148  loss_bbox: 0.1798  loss_mask: 0.3465
# 07/29 18:52:09 - mmengine - INFO - Epoch(train)  [2][250/731]  lr: 2.0000e-02  eta: 6:34:01  time: 1.1332  data_time: 0.0588  memory: 6520  loss: 0.8684  loss_rpn_cls: 0.0966  loss_rpn_bbox: 0.0890  loss_cls: 0.1704  acc: 95.1172  loss_bbox: 0.1778  loss_mask: 0.3346
# 07/29 18:52:30 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 18:53:05 - mmengine - INFO - Epoch(train)  [2][300/731]  lr: 2.0000e-02  eta: 6:33:02  time: 1.1268  data_time: 0.0549  memory: 6444  loss: 0.8705  loss_rpn_cls: 0.0892  loss_rpn_bbox: 0.0886  loss_cls: 0.1702  acc: 96.4844  loss_bbox: 0.1805  loss_mask: 0.3420
# 07/29 18:54:01 - mmengine - INFO - Epoch(train)  [2][350/731]  lr: 2.0000e-02  eta: 6:32:00  time: 1.1218  data_time: 0.0512  memory: 6459  loss: 0.8230  loss_rpn_cls: 0.0854  loss_rpn_bbox: 0.0825  loss_cls: 0.1555  acc: 92.8711  loss_bbox: 0.1663  loss_mask: 0.3333
# 07/29 18:54:57 - mmengine - INFO - Epoch(train)  [2][400/731]  lr: 2.0000e-02  eta: 6:30:54  time: 1.1180  data_time: 0.0487  memory: 6379  loss: 0.8338  loss_rpn_cls: 0.0755  loss_rpn_bbox: 0.0789  loss_cls: 0.1681  acc: 89.6484  loss_bbox: 0.1777  loss_mask: 0.3337
# 07/29 18:55:54 - mmengine - INFO - Epoch(train)  [2][450/731]  lr: 2.0000e-02  eta: 6:30:11  time: 1.1431  data_time: 0.0650  memory: 6379  loss: 0.9155  loss_rpn_cls: 0.0964  loss_rpn_bbox: 0.0932  loss_cls: 0.1863  acc: 93.8477  loss_bbox: 0.2052  loss_mask: 0.3344
# 07/29 18:56:51 - mmengine - INFO - Epoch(train)  [2][500/731]  lr: 2.0000e-02  eta: 6:29:18  time: 1.1322  data_time: 0.0577  memory: 6380  loss: 0.8476  loss_rpn_cls: 0.0917  loss_rpn_bbox: 0.0926  loss_cls: 0.1550  acc: 93.5547  loss_bbox: 0.1790  loss_mask: 0.3293
# 07/29 18:57:47 - mmengine - INFO - Epoch(train)  [2][550/731]  lr: 2.0000e-02  eta: 6:28:13  time: 1.1179  data_time: 0.0499  memory: 6478  loss: 0.8066  loss_rpn_cls: 0.0795  loss_rpn_bbox: 0.0767  loss_cls: 0.1487  acc: 97.7539  loss_bbox: 0.1693  loss_mask: 0.3324
# 07/29 18:58:43 - mmengine - INFO - Epoch(train)  [2][600/731]  lr: 2.0000e-02  eta: 6:27:13  time: 1.1241  data_time: 0.0528  memory: 6381  loss: 0.8406  loss_rpn_cls: 0.0815  loss_rpn_bbox: 0.0831  loss_cls: 0.1633  acc: 95.4102  loss_bbox: 0.1730  loss_mask: 0.3397
# 07/29 18:59:39 - mmengine - INFO - Epoch(train)  [2][650/731]  lr: 2.0000e-02  eta: 6:26:10  time: 1.1186  data_time: 0.0481  memory: 6406  loss: 0.7904  loss_rpn_cls: 0.0734  loss_rpn_bbox: 0.0832  loss_cls: 0.1465  acc: 96.3867  loss_bbox: 0.1659  loss_mask: 0.3215
# 07/29 19:00:35 - mmengine - INFO - Epoch(train)  [2][700/731]  lr: 2.0000e-02  eta: 6:25:13  time: 1.1261  data_time: 0.0546  memory: 6382  loss: 0.8111  loss_rpn_cls: 0.0728  loss_rpn_bbox: 0.0810  loss_cls: 0.1584  acc: 96.2891  loss_bbox: 0.1744  loss_mask: 0.3245
# 07/29 19:01:10 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:01:18 - mmengine - INFO - Epoch(val)  [2][ 50/163]    eta: 0:00:16  time: 0.1476  data_time: 0.0028  memory: 6537
# 07/29 19:01:25 - mmengine - INFO - Epoch(val)  [2][100/163]    eta: 0:00:09  time: 0.1459  data_time: 0.0022  memory: 1005
# 07/29 19:01:32 - mmengine - INFO - Epoch(val)  [2][150/163]    eta: 0:00:01  time: 0.1504  data_time: 0.0032  memory: 1005
# 07/29 19:01:35 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.75s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.356
# 07/29 19:01:38 - mmengine - INFO - segm_mAP_copypaste: 0.176 0.416 0.099 0.098 0.122 0.168
# 07/29 19:01:38 - mmengine - INFO - Epoch(val) [2][163/163]    coco/segm_mAP: 0.1760  coco/segm_mAP_50: 0.4160  coco/segm_mAP_75: 0.0990  coco/segm_mAP_s: 0.0980  coco/segm_mAP_m: 0.1220  coco/segm_mAP_l: 0.1680  data_time: 0.0027  time: 0.1478
# 07/29 19:01:38 - mmengine - INFO - The previous best checkpoint /kaggle/working/work_dir/best_coco_segm_mAP_epoch_1.pth is removed
# 07/29 19:01:42 - mmengine - INFO - The best checkpoint with 0.1760 coco/segm_mAP at 2 epoch is saved to best_coco_segm_mAP_epoch_2.pth.
# 07/29 19:02:38 - mmengine - INFO - Epoch(train)  [3][ 50/731]  lr: 2.0000e-02  eta: 6:23:47  time: 1.1307  data_time: 0.0561  memory: 6380  loss: 0.8188  loss_rpn_cls: 0.0800  loss_rpn_bbox: 0.0868  loss_cls: 0.1578  acc: 91.5039  loss_bbox: 0.1727  loss_mask: 0.3215
# 07/29 19:03:35 - mmengine - INFO - Epoch(train)  [3][100/731]  lr: 2.0000e-02  eta: 6:22:52  time: 1.1296  data_time: 0.0552  memory: 6522  loss: 0.8061  loss_rpn_cls: 0.0662  loss_rpn_bbox: 0.0806  loss_cls: 0.1552  acc: 97.9492  loss_bbox: 0.1909  loss_mask: 0.3132
# 07/29 19:04:30 - mmengine - INFO - Epoch(train)  [3][150/731]  lr: 2.0000e-02  eta: 6:21:46  time: 1.1131  data_time: 0.0429  memory: 6381  loss: 0.7376  loss_rpn_cls: 0.0560  loss_rpn_bbox: 0.0679  loss_cls: 0.1435  acc: 95.2148  loss_bbox: 0.1593  loss_mask: 0.3108
# 07/29 19:05:27 - mmengine - INFO - Epoch(train)  [3][200/731]  lr: 2.0000e-02  eta: 6:20:51  time: 1.1290  data_time: 0.0537  memory: 6473  loss: 0.8174  loss_rpn_cls: 0.0700  loss_rpn_bbox: 0.0799  loss_cls: 0.1715  acc: 96.2891  loss_bbox: 0.1845  loss_mask: 0.3115
# 07/29 19:06:23 - mmengine - INFO - Epoch(train)  [3][250/731]  lr: 2.0000e-02  eta: 6:19:56  time: 1.1300  data_time: 0.0553  memory: 6385  loss: 0.8357  loss_rpn_cls: 0.0813  loss_rpn_bbox: 0.0884  loss_cls: 0.1640  acc: 90.7227  loss_bbox: 0.1843  loss_mask: 0.3178
# 07/29 19:07:19 - mmengine - INFO - Epoch(train)  [3][300/731]  lr: 2.0000e-02  eta: 6:18:51  time: 1.1129  data_time: 0.0467  memory: 6381  loss: 0.7485  loss_rpn_cls: 0.0652  loss_rpn_bbox: 0.0778  loss_cls: 0.1410  acc: 93.1641  loss_bbox: 0.1584  loss_mask: 0.3061
# 07/29 19:08:16 - mmengine - INFO - Epoch(train)  [3][350/731]  lr: 2.0000e-02  eta: 6:17:59  time: 1.1338  data_time: 0.0553  memory: 6378  loss: 0.7795  loss_rpn_cls: 0.0598  loss_rpn_bbox: 0.0814  loss_cls: 0.1548  acc: 95.5078  loss_bbox: 0.1897  loss_mask: 0.2937
# 07/29 19:09:12 - mmengine - INFO - Epoch(train)  [3][400/731]  lr: 2.0000e-02  eta: 6:16:58  time: 1.1184  data_time: 0.0481  memory: 6380  loss: 0.7341  loss_rpn_cls: 0.0549  loss_rpn_bbox: 0.0632  loss_cls: 0.1416  acc: 94.2383  loss_bbox: 0.1641  loss_mask: 0.3102
# 07/29 19:10:08 - mmengine - INFO - Epoch(train)  [3][450/731]  lr: 2.0000e-02  eta: 6:16:04  time: 1.1332  data_time: 0.0557  memory: 6513  loss: 0.8132  loss_rpn_cls: 0.0662  loss_rpn_bbox: 0.0832  loss_cls: 0.1663  acc: 94.8242  loss_bbox: 0.1920  loss_mask: 0.3054
# 07/29 19:11:05 - mmengine - INFO - Epoch(train)  [3][500/731]  lr: 2.0000e-02  eta: 6:15:10  time: 1.1304  data_time: 0.0562  memory: 6381  loss: 0.7906  loss_rpn_cls: 0.0666  loss_rpn_bbox: 0.0766  loss_cls: 0.1520  acc: 95.1172  loss_bbox: 0.1784  loss_mask: 0.3170
# 07/29 19:11:48 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:12:01 - mmengine - INFO - Epoch(train)  [3][550/731]  lr: 2.0000e-02  eta: 6:14:12  time: 1.1254  data_time: 0.0524  memory: 6429  loss: 0.7941  loss_rpn_cls: 0.0654  loss_rpn_bbox: 0.0781  loss_cls: 0.1572  acc: 90.1367  loss_bbox: 0.1819  loss_mask: 0.3115
# 07/29 19:12:57 - mmengine - INFO - Epoch(train)  [3][600/731]  lr: 2.0000e-02  eta: 6:13:16  time: 1.1266  data_time: 0.0524  memory: 6478  loss: 0.7833  loss_rpn_cls: 0.0645  loss_rpn_bbox: 0.0795  loss_cls: 0.1563  acc: 97.2656  loss_bbox: 0.1732  loss_mask: 0.3097
# 07/29 19:13:53 - mmengine - INFO - Epoch(train)  [3][650/731]  lr: 2.0000e-02  eta: 6:12:13  time: 1.1137  data_time: 0.0451  memory: 6381  loss: 0.7400  loss_rpn_cls: 0.0566  loss_rpn_bbox: 0.0647  loss_cls: 0.1400  acc: 97.6562  loss_bbox: 0.1584  loss_mask: 0.3203
# 07/29 19:14:49 - mmengine - INFO - Epoch(train)  [3][700/731]  lr: 2.0000e-02  eta: 6:11:17  time: 1.1278  data_time: 0.0523  memory: 6564  loss: 0.7649  loss_rpn_cls: 0.0640  loss_rpn_bbox: 0.0760  loss_cls: 0.1472  acc: 96.1914  loss_bbox: 0.1730  loss_mask: 0.3047
# 07/29 19:15:24 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:15:24 - mmengine - INFO - Saving checkpoint at 3 epochs
# 07/29 19:15:35 - mmengine - INFO - Epoch(val)  [3][ 50/163]    eta: 0:00:16  time: 0.1493  data_time: 0.0027  memory: 6447
# 07/29 19:15:43 - mmengine - INFO - Epoch(val)  [3][100/163]    eta: 0:00:09  time: 0.1465  data_time: 0.0022  memory: 1005
# 07/29 19:15:50 - mmengine - INFO - Epoch(val)  [3][150/163]    eta: 0:00:01  time: 0.1488  data_time: 0.0026  memory: 1005
# 07/29 19:15:53 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.75s).
# Accumulating evaluation results...
# DONE (t=0.31s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.554
# 07/29 19:15:56 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.557 0.215 0.126 0.193 0.274
# 07/29 19:15:56 - mmengine - INFO - Epoch(val) [3][163/163]    coco/segm_mAP: 0.2720  coco/segm_mAP_50: 0.5570  coco/segm_mAP_75: 0.2150  coco/segm_mAP_s: 0.1260  coco/segm_mAP_m: 0.1930  coco/segm_mAP_l: 0.2740  data_time: 0.0025  time: 0.1478
# 07/29 19:15:56 - mmengine - INFO - The previous best checkpoint /kaggle/working/work_dir/best_coco_segm_mAP_epoch_2.pth is removed
# 07/29 19:15:59 - mmengine - INFO - The best checkpoint with 0.2720 coco/segm_mAP at 3 epoch is saved to best_coco_segm_mAP_epoch_3.pth.
# 07/29 19:16:56 - mmengine - INFO - Epoch(train)  [4][ 50/731]  lr: 2.0000e-02  eta: 6:09:40  time: 1.1255  data_time: 0.0539  memory: 6381  loss: 0.7413  loss_rpn_cls: 0.0531  loss_rpn_bbox: 0.0676  loss_cls: 0.1414  acc: 95.6055  loss_bbox: 0.1552  loss_mask: 0.3241
# 07/29 19:17:52 - mmengine - INFO - Epoch(train)  [4][100/731]  lr: 2.0000e-02  eta: 6:08:42  time: 1.1214  data_time: 0.0492  memory: 6381  loss: 0.7395  loss_rpn_cls: 0.0641  loss_rpn_bbox: 0.0713  loss_cls: 0.1382  acc: 94.5312  loss_bbox: 0.1566  loss_mask: 0.3093
# 07/29 19:18:48 - mmengine - INFO - Epoch(train)  [4][150/731]  lr: 2.0000e-02  eta: 6:07:42  time: 1.1181  data_time: 0.0455  memory: 6380  loss: 0.7357  loss_rpn_cls: 0.0531  loss_rpn_bbox: 0.0720  loss_cls: 0.1458  acc: 95.4102  loss_bbox: 0.1620  loss_mask: 0.3028
# 07/29 19:19:44 - mmengine - INFO - Epoch(train)  [4][200/731]  lr: 2.0000e-02  eta: 6:06:46  time: 1.1269  data_time: 0.0522  memory: 6487  loss: 0.7346  loss_rpn_cls: 0.0500  loss_rpn_bbox: 0.0739  loss_cls: 0.1482  acc: 93.3594  loss_bbox: 0.1684  loss_mask: 0.2940
# 07/29 19:20:40 - mmengine - INFO - Epoch(train)  [4][250/731]  lr: 2.0000e-02  eta: 6:05:45  time: 1.1159  data_time: 0.0475  memory: 6392  loss: 0.7232  loss_rpn_cls: 0.0527  loss_rpn_bbox: 0.0692  loss_cls: 0.1401  acc: 95.2148  loss_bbox: 0.1585  loss_mask: 0.3026
# 07/29 19:21:36 - mmengine - INFO - Epoch(train)  [4][300/731]  lr: 2.0000e-02  eta: 6:04:50  time: 1.1284  data_time: 0.0537  memory: 6379  loss: 0.7580  loss_rpn_cls: 0.0555  loss_rpn_bbox: 0.0836  loss_cls: 0.1497  acc: 94.7266  loss_bbox: 0.1786  loss_mask: 0.2906
# 07/29 19:22:33 - mmengine - INFO - Epoch(train)  [4][350/731]  lr: 2.0000e-02  eta: 6:03:57  time: 1.1345  data_time: 0.0571  memory: 6559  loss: 0.7798  loss_rpn_cls: 0.0624  loss_rpn_bbox: 0.0776  loss_cls: 0.1523  acc: 92.8711  loss_bbox: 0.1884  loss_mask: 0.2991
# 07/29 19:23:29 - mmengine - INFO - Epoch(train)  [4][400/731]  lr: 2.0000e-02  eta: 6:02:58  time: 1.1196  data_time: 0.0484  memory: 6380  loss: 0.7316  loss_rpn_cls: 0.0528  loss_rpn_bbox: 0.0730  loss_cls: 0.1442  acc: 94.8242  loss_bbox: 0.1628  loss_mask: 0.2988
# 07/29 19:24:25 - mmengine - INFO - Epoch(train)  [4][450/731]  lr: 2.0000e-02  eta: 6:01:59  time: 1.1199  data_time: 0.0461  memory: 6384  loss: 0.7502  loss_rpn_cls: 0.0582  loss_rpn_bbox: 0.0750  loss_cls: 0.1443  acc: 92.1875  loss_bbox: 0.1668  loss_mask: 0.3060
# 07/29 19:25:21 - mmengine - INFO - Epoch(train)  [4][500/731]  lr: 2.0000e-02  eta: 6:01:02  time: 1.1228  data_time: 0.0490  memory: 6381  loss: 0.7618  loss_rpn_cls: 0.0643  loss_rpn_bbox: 0.0723  loss_cls: 0.1519  acc: 93.3594  loss_bbox: 0.1716  loss_mask: 0.3016
# 07/29 19:26:17 - mmengine - INFO - Epoch(train)  [4][550/731]  lr: 2.0000e-02  eta: 6:00:06  time: 1.1264  data_time: 0.0523  memory: 6492  loss: 0.7325  loss_rpn_cls: 0.0563  loss_rpn_bbox: 0.0719  loss_cls: 0.1447  acc: 92.5781  loss_bbox: 0.1690  loss_mask: 0.2906
# 07/29 19:27:14 - mmengine - INFO - Epoch(train)  [4][600/731]  lr: 2.0000e-02  eta: 5:59:09  time: 1.1240  data_time: 0.0493  memory: 6469  loss: 0.7153  loss_rpn_cls: 0.0456  loss_rpn_bbox: 0.0707  loss_cls: 0.1320  acc: 95.3125  loss_bbox: 0.1700  loss_mask: 0.2969
# 07/29 19:28:10 - mmengine - INFO - Epoch(train)  [4][650/731]  lr: 2.0000e-02  eta: 5:58:13  time: 1.1281  data_time: 0.0512  memory: 6390  loss: 0.7378  loss_rpn_cls: 0.0539  loss_rpn_bbox: 0.0726  loss_cls: 0.1420  acc: 94.9219  loss_bbox: 0.1695  loss_mask: 0.2998
# 07/29 19:29:06 - mmengine - INFO - Epoch(train)  [4][700/731]  lr: 2.0000e-02  eta: 5:57:17  time: 1.1281  data_time: 0.0500  memory: 6518  loss: 0.7752  loss_rpn_cls: 0.0621  loss_rpn_bbox: 0.0751  loss_cls: 0.1482  acc: 97.4609  loss_bbox: 0.1780  loss_mask: 0.3120
# 07/29 19:29:41 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:29:49 - mmengine - INFO - Epoch(val)  [4][ 50/163]    eta: 0:00:16  time: 0.1494  data_time: 0.0029  memory: 6381
# 07/29 19:29:56 - mmengine - INFO - Epoch(val)  [4][100/163]    eta: 0:00:09  time: 0.1477  data_time: 0.0023  memory: 1005
# 07/29 19:30:04 - mmengine - INFO - Epoch(val)  [4][150/163]    eta: 0:00:01  time: 0.1518  data_time: 0.0035  memory: 1005
# 07/29 19:30:06 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.70s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.231
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.288
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.533
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.533
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.533
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.227
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.506
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.524
# 07/29 19:30:09 - mmengine - INFO - segm_mAP_copypaste: 0.307 0.582 0.284 0.146 0.231 0.288
# 07/29 19:30:09 - mmengine - INFO - Epoch(val) [4][163/163]    coco/segm_mAP: 0.3070  coco/segm_mAP_50: 0.5820  coco/segm_mAP_75: 0.2840  coco/segm_mAP_s: 0.1460  coco/segm_mAP_m: 0.2310  coco/segm_mAP_l: 0.2880  data_time: 0.0029  time: 0.1496
# 07/29 19:30:09 - mmengine - INFO - The previous best checkpoint /kaggle/working/work_dir/best_coco_segm_mAP_epoch_3.pth is removed
# 07/29 19:30:13 - mmengine - INFO - The best checkpoint with 0.3070 coco/segm_mAP at 4 epoch is saved to best_coco_segm_mAP_epoch_4.pth.
# 07/29 19:31:10 - mmengine - INFO - Epoch(train)  [5][ 50/731]  lr: 2.0000e-02  eta: 5:55:48  time: 1.1336  data_time: 0.0587  memory: 6489  loss: 0.7270  loss_rpn_cls: 0.0549  loss_rpn_bbox: 0.0721  loss_cls: 0.1387  acc: 95.8984  loss_bbox: 0.1663  loss_mask: 0.2949
# 07/29 19:31:39 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:32:06 - mmengine - INFO - Epoch(train)  [5][100/731]  lr: 2.0000e-02  eta: 5:54:50  time: 1.1209  data_time: 0.0490  memory: 6462  loss: 0.6892  loss_rpn_cls: 0.0465  loss_rpn_bbox: 0.0666  loss_cls: 0.1338  acc: 96.7773  loss_bbox: 0.1575  loss_mask: 0.2848
# 07/29 19:33:02 - mmengine - INFO - Epoch(train)  [5][150/731]  lr: 2.0000e-02  eta: 5:53:52  time: 1.1207  data_time: 0.0483  memory: 6381  loss: 0.7019  loss_rpn_cls: 0.0486  loss_rpn_bbox: 0.0701  loss_cls: 0.1334  acc: 95.8008  loss_bbox: 0.1581  loss_mask: 0.2917
# 07/29 19:33:58 - mmengine - INFO - Epoch(train)  [5][200/731]  lr: 2.0000e-02  eta: 5:52:53  time: 1.1166  data_time: 0.0451  memory: 6379  loss: 0.7015  loss_rpn_cls: 0.0436  loss_rpn_bbox: 0.0645  loss_cls: 0.1377  acc: 96.1914  loss_bbox: 0.1654  loss_mask: 0.2903
# 07/29 19:34:54 - mmengine - INFO - Epoch(train)  [5][250/731]  lr: 2.0000e-02  eta: 5:51:57  time: 1.1277  data_time: 0.0491  memory: 6465  loss: 0.7569  loss_rpn_cls: 0.0550  loss_rpn_bbox: 0.0757  loss_cls: 0.1513  acc: 92.7734  loss_bbox: 0.1764  loss_mask: 0.2986
# 07/29 19:35:50 - mmengine - INFO - Epoch(train)  [5][300/731]  lr: 2.0000e-02  eta: 5:50:58  time: 1.1156  data_time: 0.0453  memory: 6404  loss: 0.6782  loss_rpn_cls: 0.0469  loss_rpn_bbox: 0.0645  loss_cls: 0.1264  acc: 96.4844  loss_bbox: 0.1491  loss_mask: 0.2913
# 07/29 19:36:46 - mmengine - INFO - Epoch(train)  [5][350/731]  lr: 2.0000e-02  eta: 5:49:59  time: 1.1158  data_time: 0.0446  memory: 6380  loss: 0.6887  loss_rpn_cls: 0.0468  loss_rpn_bbox: 0.0669  loss_cls: 0.1336  acc: 96.9727  loss_bbox: 0.1583  loss_mask: 0.2832
# 07/29 19:37:42 - mmengine - INFO - Epoch(train)  [5][400/731]  lr: 2.0000e-02  eta: 5:49:03  time: 1.1248  data_time: 0.0504  memory: 6557  loss: 0.7332  loss_rpn_cls: 0.0567  loss_rpn_bbox: 0.0697  loss_cls: 0.1497  acc: 95.0195  loss_bbox: 0.1715  loss_mask: 0.2857
# 07/29 19:38:38 - mmengine - INFO - Epoch(train)  [5][450/731]  lr: 2.0000e-02  eta: 5:48:07  time: 1.1294  data_time: 0.0525  memory: 6386  loss: 0.7442  loss_rpn_cls: 0.0507  loss_rpn_bbox: 0.0769  loss_cls: 0.1432  acc: 91.5039  loss_bbox: 0.1713  loss_mask: 0.3021
# 07/29 19:39:34 - mmengine - INFO - Epoch(train)  [5][500/731]  lr: 2.0000e-02  eta: 5:47:10  time: 1.1216  data_time: 0.0490  memory: 6435  loss: 0.7111  loss_rpn_cls: 0.0566  loss_rpn_bbox: 0.0704  loss_cls: 0.1375  acc: 95.1172  loss_bbox: 0.1549  loss_mask: 0.2918
# 07/29 19:40:31 - mmengine - INFO - Epoch(train)  [5][550/731]  lr: 2.0000e-02  eta: 5:46:14  time: 1.1256  data_time: 0.0491  memory: 6516  loss: 0.7352  loss_rpn_cls: 0.0526  loss_rpn_bbox: 0.0809  loss_cls: 0.1397  acc: 94.3359  loss_bbox: 0.1759  loss_mask: 0.2862
# 07/29 19:41:27 - mmengine - INFO - Epoch(train)  [5][600/731]  lr: 2.0000e-02  eta: 5:45:17  time: 1.1249  data_time: 0.0509  memory: 6380  loss: 0.7391  loss_rpn_cls: 0.0561  loss_rpn_bbox: 0.0751  loss_cls: 0.1463  acc: 95.7031  loss_bbox: 0.1709  loss_mask: 0.2907
# 07/29 19:42:23 - mmengine - INFO - Epoch(train)  [5][650/731]  lr: 2.0000e-02  eta: 5:44:18  time: 1.1152  data_time: 0.0431  memory: 6381  loss: 0.7087  loss_rpn_cls: 0.0461  loss_rpn_bbox: 0.0625  loss_cls: 0.1403  acc: 93.4570  loss_bbox: 0.1688  loss_mask: 0.2910
# 07/29 19:43:19 - mmengine - INFO - Epoch(train)  [5][700/731]  lr: 2.0000e-02  eta: 5:43:22  time: 1.1274  data_time: 0.0503  memory: 6488  loss: 0.7287  loss_rpn_cls: 0.0490  loss_rpn_bbox: 0.0699  loss_cls: 0.1428  acc: 90.6250  loss_bbox: 0.1808  loss_mask: 0.2862
# 07/29 19:43:54 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:44:02 - mmengine - INFO - Epoch(val)  [5][ 50/163]    eta: 0:00:16  time: 0.1490  data_time: 0.0029  memory: 6528
# 07/29 19:44:09 - mmengine - INFO - Epoch(val)  [5][100/163]    eta: 0:00:09  time: 0.1477  data_time: 0.0021  memory: 1005
# 07/29 19:44:17 - mmengine - INFO - Epoch(val)  [5][150/163]    eta: 0:00:01  time: 0.1532  data_time: 0.0039  memory: 1005
# 07/29 19:44:19 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.71s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.590
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.527
# 07/29 19:44:22 - mmengine - INFO - segm_mAP_copypaste: 0.261 0.590 0.186 0.143 0.203 0.314
# 07/29 19:44:22 - mmengine - INFO - Epoch(val) [5][163/163]    coco/segm_mAP: 0.2610  coco/segm_mAP_50: 0.5900  coco/segm_mAP_75: 0.1860  coco/segm_mAP_s: 0.1430  coco/segm_mAP_m: 0.2030  coco/segm_mAP_l: 0.3140  data_time: 0.0029  time: 0.1497
# 07/29 19:45:18 - mmengine - INFO - Epoch(train)  [6][ 50/731]  lr: 2.0000e-02  eta: 5:41:52  time: 1.1245  data_time: 0.0519  memory: 6413  loss: 0.6837  loss_rpn_cls: 0.0419  loss_rpn_bbox: 0.0672  loss_cls: 0.1370  acc: 95.8984  loss_bbox: 0.1636  loss_mask: 0.2740
# 07/29 19:46:15 - mmengine - INFO - Epoch(train)  [6][100/731]  lr: 2.0000e-02  eta: 5:40:57  time: 1.1325  data_time: 0.0533  memory: 6490  loss: 0.7273  loss_rpn_cls: 0.0475  loss_rpn_bbox: 0.0685  loss_cls: 0.1485  acc: 94.3359  loss_bbox: 0.1826  loss_mask: 0.2801
# 07/29 19:47:11 - mmengine - INFO - Epoch(train)  [6][150/731]  lr: 2.0000e-02  eta: 5:40:02  time: 1.1278  data_time: 0.0516  memory: 6473  loss: 0.7353  loss_rpn_cls: 0.0576  loss_rpn_bbox: 0.0733  loss_cls: 0.1446  acc: 94.2383  loss_bbox: 0.1740  loss_mask: 0.2858
# 07/29 19:48:07 - mmengine - INFO - Epoch(train)  [6][200/731]  lr: 2.0000e-02  eta: 5:39:03  time: 1.1159  data_time: 0.0451  memory: 6381  loss: 0.6560  loss_rpn_cls: 0.0432  loss_rpn_bbox: 0.0572  loss_cls: 0.1221  acc: 94.4336  loss_bbox: 0.1453  loss_mask: 0.2883
# 07/29 19:49:03 - mmengine - INFO - Epoch(train)  [6][250/731]  lr: 2.0000e-02  eta: 5:38:03  time: 1.1099  data_time: 0.0402  memory: 6521  loss: 0.6841  loss_rpn_cls: 0.0461  loss_rpn_bbox: 0.0650  loss_cls: 0.1273  acc: 99.0234  loss_bbox: 0.1574  loss_mask: 0.2885
# 07/29 19:49:59 - mmengine - INFO - Epoch(train)  [6][300/731]  lr: 2.0000e-02  eta: 5:37:07  time: 1.1251  data_time: 0.0491  memory: 6409  loss: 0.7254  loss_rpn_cls: 0.0515  loss_rpn_bbox: 0.0718  loss_cls: 0.1393  acc: 92.6758  loss_bbox: 0.1690  loss_mask: 0.2938
# 07/29 19:50:50 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:50:55 - mmengine - INFO - Epoch(train)  [6][350/731]  lr: 2.0000e-02  eta: 5:36:11  time: 1.1267  data_time: 0.0502  memory: 6538  loss: 0.6952  loss_rpn_cls: 0.0437  loss_rpn_bbox: 0.0651  loss_cls: 0.1402  acc: 95.7031  loss_bbox: 0.1706  loss_mask: 0.2756
# 07/29 19:51:52 - mmengine - INFO - Epoch(train)  [6][400/731]  lr: 2.0000e-02  eta: 5:35:15  time: 1.1269  data_time: 0.0501  memory: 6496  loss: 0.7077  loss_rpn_cls: 0.0409  loss_rpn_bbox: 0.0720  loss_cls: 0.1371  acc: 92.7734  loss_bbox: 0.1720  loss_mask: 0.2856
# 07/29 19:52:48 - mmengine - INFO - Epoch(train)  [6][450/731]  lr: 2.0000e-02  eta: 5:34:18  time: 1.1236  data_time: 0.0483  memory: 6381  loss: 0.7072  loss_rpn_cls: 0.0491  loss_rpn_bbox: 0.0717  loss_cls: 0.1402  acc: 94.1406  loss_bbox: 0.1676  loss_mask: 0.2786
# 07/29 19:53:44 - mmengine - INFO - Epoch(train)  [6][500/731]  lr: 2.0000e-02  eta: 5:33:21  time: 1.1213  data_time: 0.0479  memory: 6578  loss: 0.7477  loss_rpn_cls: 0.0507  loss_rpn_bbox: 0.0749  loss_cls: 0.1436  acc: 96.8750  loss_bbox: 0.1692  loss_mask: 0.3093
# 07/29 19:54:40 - mmengine - INFO - Epoch(train)  [6][550/731]  lr: 2.0000e-02  eta: 5:32:23  time: 1.1154  data_time: 0.0445  memory: 6380  loss: 0.7028  loss_rpn_cls: 0.0424  loss_rpn_bbox: 0.0641  loss_cls: 0.1383  acc: 93.4570  loss_bbox: 0.1625  loss_mask: 0.2955
# 07/29 19:55:35 - mmengine - INFO - Epoch(train)  [6][600/731]  lr: 2.0000e-02  eta: 5:31:24  time: 1.1123  data_time: 0.0429  memory: 6379  loss: 0.6629  loss_rpn_cls: 0.0417  loss_rpn_bbox: 0.0617  loss_cls: 0.1317  acc: 95.1172  loss_bbox: 0.1503  loss_mask: 0.2775
# 07/29 19:56:31 - mmengine - INFO - Epoch(train)  [6][650/731]  lr: 2.0000e-02  eta: 5:30:26  time: 1.1151  data_time: 0.0440  memory: 6382  loss: 0.6571  loss_rpn_cls: 0.0444  loss_rpn_bbox: 0.0645  loss_cls: 0.1274  acc: 96.0938  loss_bbox: 0.1452  loss_mask: 0.2757
# 07/29 19:57:27 - mmengine - INFO - Epoch(train)  [6][700/731]  lr: 2.0000e-02  eta: 5:29:29  time: 1.1214  data_time: 0.0482  memory: 6380  loss: 0.7056  loss_rpn_cls: 0.0513  loss_rpn_bbox: 0.0701  loss_cls: 0.1345  acc: 92.8711  loss_bbox: 0.1587  loss_mask: 0.2911
# 07/29 19:58:03 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 19:58:03 - mmengine - INFO - Saving checkpoint at 6 epochs
# 07/29 19:58:14 - mmengine - INFO - Epoch(val)  [6][ 50/163]    eta: 0:00:16  time: 0.1503  data_time: 0.0027  memory: 6474
# 07/29 19:58:21 - mmengine - INFO - Epoch(val)  [6][100/163]    eta: 0:00:09  time: 0.1482  data_time: 0.0021  memory: 1005
# 07/29 19:58:29 - mmengine - INFO - Epoch(val)  [6][150/163]    eta: 0:00:01  time: 0.1479  data_time: 0.0026  memory: 1005
# 07/29 19:58:32 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.84s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.645
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.218
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.506
# 07/29 19:58:35 - mmengine - INFO - segm_mAP_copypaste: 0.359 0.645 0.317 0.134 0.218 0.374
# 07/29 19:58:35 - mmengine - INFO - Epoch(val) [6][163/163]    coco/segm_mAP: 0.3590  coco/segm_mAP_50: 0.6450  coco/segm_mAP_75: 0.3170  coco/segm_mAP_s: 0.1340  coco/segm_mAP_m: 0.2180  coco/segm_mAP_l: 0.3740  data_time: 0.0025  time: 0.1495
# 07/29 19:58:35 - mmengine - INFO - The previous best checkpoint /kaggle/working/work_dir/best_coco_segm_mAP_epoch_4.pth is removed
# 07/29 19:58:39 - mmengine - INFO - The best checkpoint with 0.3590 coco/segm_mAP at 6 epoch is saved to best_coco_segm_mAP_epoch_6.pth.
# 07/29 19:59:35 - mmengine - INFO - Epoch(train)  [7][ 50/731]  lr: 2.0000e-02  eta: 5:27:59  time: 1.1237  data_time: 0.0494  memory: 6451  loss: 0.6725  loss_rpn_cls: 0.0381  loss_rpn_bbox: 0.0654  loss_cls: 0.1347  acc: 94.0430  loss_bbox: 0.1634  loss_mask: 0.2710
# 07/29 20:00:31 - mmengine - INFO - Epoch(train)  [7][100/731]  lr: 2.0000e-02  eta: 5:27:03  time: 1.1253  data_time: 0.0499  memory: 6460  loss: 0.7048  loss_rpn_cls: 0.0447  loss_rpn_bbox: 0.0762  loss_cls: 0.1402  acc: 94.5312  loss_bbox: 0.1643  loss_mask: 0.2794
# 07/29 20:01:27 - mmengine - INFO - Epoch(train)  [7][150/731]  lr: 2.0000e-02  eta: 5:26:07  time: 1.1287  data_time: 0.0512  memory: 6405  loss: 0.6858  loss_rpn_cls: 0.0449  loss_rpn_bbox: 0.0704  loss_cls: 0.1318  acc: 95.4102  loss_bbox: 0.1674  loss_mask: 0.2713
# 07/29 20:02:24 - mmengine - INFO - Epoch(train)  [7][200/731]  lr: 2.0000e-02  eta: 5:25:11  time: 1.1238  data_time: 0.0481  memory: 6447  loss: 0.7226  loss_rpn_cls: 0.0485  loss_rpn_bbox: 0.0726  loss_cls: 0.1413  acc: 96.5820  loss_bbox: 0.1770  loss_mask: 0.2833
# 07/29 20:03:20 - mmengine - INFO - Epoch(train)  [7][250/731]  lr: 2.0000e-02  eta: 5:24:13  time: 1.1182  data_time: 0.0438  memory: 6406  loss: 0.6573  loss_rpn_cls: 0.0381  loss_rpn_bbox: 0.0596  loss_cls: 0.1332  acc: 94.3359  loss_bbox: 0.1534  loss_mask: 0.2730
# 07/29 20:04:16 - mmengine - INFO - Epoch(train)  [7][300/731]  lr: 2.0000e-02  eta: 5:23:19  time: 1.1323  data_time: 0.0541  memory: 6511  loss: 0.6998  loss_rpn_cls: 0.0518  loss_rpn_bbox: 0.0691  loss_cls: 0.1394  acc: 89.5508  loss_bbox: 0.1680  loss_mask: 0.2714
# 07/29 20:05:12 - mmengine - INFO - Epoch(train)  [7][350/731]  lr: 2.0000e-02  eta: 5:22:22  time: 1.1245  data_time: 0.0498  memory: 6504  loss: 0.6616  loss_rpn_cls: 0.0372  loss_rpn_bbox: 0.0672  loss_cls: 0.1224  acc: 96.9727  loss_bbox: 0.1560  loss_mask: 0.2787
# 07/29 20:06:08 - mmengine - INFO - Epoch(train)  [7][400/731]  lr: 2.0000e-02  eta: 5:21:25  time: 1.1167  data_time: 0.0465  memory: 6380  loss: 0.6749  loss_rpn_cls: 0.0428  loss_rpn_bbox: 0.0625  loss_cls: 0.1355  acc: 95.3125  loss_bbox: 0.1521  loss_mask: 0.2820
# 07/29 20:07:04 - mmengine - INFO - Epoch(train)  [7][450/731]  lr: 2.0000e-02  eta: 5:20:26  time: 1.1136  data_time: 0.0452  memory: 6381  loss: 0.6235  loss_rpn_cls: 0.0380  loss_rpn_bbox: 0.0583  loss_cls: 0.1176  acc: 91.9922  loss_bbox: 0.1356  loss_mask: 0.2740
# 07/29 20:08:00 - mmengine - INFO - Epoch(train)  [7][500/731]  lr: 2.0000e-02  eta: 5:19:30  time: 1.1268  data_time: 0.0510  memory: 6540  loss: 0.6904  loss_rpn_cls: 0.0393  loss_rpn_bbox: 0.0695  loss_cls: 0.1333  acc: 95.2148  loss_bbox: 0.1683  loss_mask: 0.2800
# 07/29 20:08:57 - mmengine - INFO - Epoch(train)  [7][550/731]  lr: 2.0000e-02  eta: 5:18:35  time: 1.1277  data_time: 0.0529  memory: 6536  loss: 0.6928  loss_rpn_cls: 0.0420  loss_rpn_bbox: 0.0689  loss_cls: 0.1366  acc: 96.5820  loss_bbox: 0.1609  loss_mask: 0.2844
# 07/29 20:09:53 - mmengine - INFO - Epoch(train)  [7][600/731]  lr: 2.0000e-02  eta: 5:17:39  time: 1.1273  data_time: 0.0515  memory: 6493  loss: 0.6811  loss_rpn_cls: 0.0413  loss_rpn_bbox: 0.0668  loss_cls: 0.1388  acc: 96.5820  loss_bbox: 0.1598  loss_mask: 0.2745
# 07/29 20:10:09 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 20:10:49 - mmengine - INFO - Epoch(train)  [7][650/731]  lr: 2.0000e-02  eta: 5:16:42  time: 1.1199  data_time: 0.0478  memory: 6384  loss: 0.6648  loss_rpn_cls: 0.0381  loss_rpn_bbox: 0.0686  loss_cls: 0.1287  acc: 93.6523  loss_bbox: 0.1570  loss_mask: 0.2724
# 07/29 20:11:45 - mmengine - INFO - Epoch(train)  [7][700/731]  lr: 2.0000e-02  eta: 5:15:46  time: 1.1254  data_time: 0.0498  memory: 6380  loss: 0.7003  loss_rpn_cls: 0.0459  loss_rpn_bbox: 0.0625  loss_cls: 0.1391  acc: 93.5547  loss_bbox: 0.1633  loss_mask: 0.2895
# 07/29 20:12:20 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 20:12:27 - mmengine - INFO - Epoch(val)  [7][ 50/163]    eta: 0:00:16  time: 0.1468  data_time: 0.0028  memory: 6454
# 07/29 20:12:34 - mmengine - INFO - Epoch(val)  [7][100/163]    eta: 0:00:09  time: 0.1452  data_time: 0.0022  memory: 1005
# 07/29 20:12:42 - mmengine - INFO - Epoch(val)  [7][150/163]    eta: 0:00:01  time: 0.1447  data_time: 0.0022  memory: 1005
# 07/29 20:12:44 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=3.27s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.539
# 07/29 20:12:48 - mmengine - INFO - segm_mAP_copypaste: 0.396 0.689 0.394 0.148 0.281 0.425
# 07/29 20:12:48 - mmengine - INFO - Epoch(val) [7][163/163]    coco/segm_mAP: 0.3960  coco/segm_mAP_50: 0.6890  coco/segm_mAP_75: 0.3940  coco/segm_mAP_s: 0.1480  coco/segm_mAP_m: 0.2810  coco/segm_mAP_l: 0.4250  data_time: 0.0024  time: 0.1454
# 07/29 20:12:48 - mmengine - INFO - The previous best checkpoint /kaggle/working/work_dir/best_coco_segm_mAP_epoch_6.pth is removed
# 07/29 20:12:51 - mmengine - INFO - The best checkpoint with 0.3960 coco/segm_mAP at 7 epoch is saved to best_coco_segm_mAP_epoch_7.pth.
# 07/29 20:13:47 - mmengine - INFO - Epoch(train)  [8][ 50/731]  lr: 2.0000e-02  eta: 5:14:12  time: 1.1187  data_time: 0.0463  memory: 6380  loss: 0.6432  loss_rpn_cls: 0.0369  loss_rpn_bbox: 0.0584  loss_cls: 0.1238  acc: 95.5078  loss_bbox: 0.1440  loss_mask: 0.2801
# 07/29 20:14:43 - mmengine - INFO - Epoch(train)  [8][100/731]  lr: 2.0000e-02  eta: 5:13:16  time: 1.1207  data_time: 0.0472  memory: 6382  loss: 0.6463  loss_rpn_cls: 0.0391  loss_rpn_bbox: 0.0613  loss_cls: 0.1309  acc: 94.8242  loss_bbox: 0.1459  loss_mask: 0.2692
# 07/29 20:15:39 - mmengine - INFO - Epoch(train)  [8][150/731]  lr: 2.0000e-02  eta: 5:12:19  time: 1.1244  data_time: 0.0491  memory: 6381  loss: 0.6562  loss_rpn_cls: 0.0357  loss_rpn_bbox: 0.0667  loss_cls: 0.1276  acc: 95.9961  loss_bbox: 0.1547  loss_mask: 0.2715
# 07/29 20:16:36 - mmengine - INFO - Epoch(train)  [8][200/731]  lr: 2.0000e-02  eta: 5:11:24  time: 1.1283  data_time: 0.0501  memory: 6462  loss: 0.6635  loss_rpn_cls: 0.0337  loss_rpn_bbox: 0.0677  loss_cls: 0.1276  acc: 91.1133  loss_bbox: 0.1638  loss_mask: 0.2708
# 07/29 20:17:32 - mmengine - INFO - Epoch(train)  [8][250/731]  lr: 2.0000e-02  eta: 5:10:26  time: 1.1142  data_time: 0.0421  memory: 6382  loss: 0.6365  loss_rpn_cls: 0.0417  loss_rpn_bbox: 0.0571  loss_cls: 0.1183  acc: 92.8711  loss_bbox: 0.1401  loss_mask: 0.2792
# 07/29 20:18:28 - mmengine - INFO - Epoch(train)  [8][300/731]  lr: 2.0000e-02  eta: 5:09:31  time: 1.1351  data_time: 0.0524  memory: 6674  loss: 0.6987  loss_rpn_cls: 0.0361  loss_rpn_bbox: 0.0737  loss_cls: 0.1396  acc: 97.1680  loss_bbox: 0.1749  loss_mask: 0.2743
# 07/29 20:19:24 - mmengine - INFO - Epoch(train)  [8][350/731]  lr: 2.0000e-02  eta: 5:08:34  time: 1.1203  data_time: 0.0461  memory: 6486  loss: 0.6513  loss_rpn_cls: 0.0414  loss_rpn_bbox: 0.0673  loss_cls: 0.1259  acc: 98.4375  loss_bbox: 0.1519  loss_mask: 0.2647
# 07/29 20:20:20 - mmengine - INFO - Epoch(train)  [8][400/731]  lr: 2.0000e-02  eta: 5:07:38  time: 1.1216  data_time: 0.0461  memory: 6528  loss: 0.6684  loss_rpn_cls: 0.0346  loss_rpn_bbox: 0.0637  loss_cls: 0.1257  acc: 95.0195  loss_bbox: 0.1665  loss_mask: 0.2779
# 07/29 20:21:17 - mmengine - INFO - Epoch(train)  [8][450/731]  lr: 2.0000e-02  eta: 5:06:43  time: 1.1332  data_time: 0.0525  memory: 6443  loss: 0.6839  loss_rpn_cls: 0.0361  loss_rpn_bbox: 0.0701  loss_cls: 0.1336  acc: 94.8242  loss_bbox: 0.1702  loss_mask: 0.2739
# 07/29 20:22:13 - mmengine - INFO - Epoch(train)  [8][500/731]  lr: 2.0000e-02  eta: 5:05:47  time: 1.1269  data_time: 0.0475  memory: 6447  loss: 0.6755  loss_rpn_cls: 0.0364  loss_rpn_bbox: 0.0661  loss_cls: 0.1314  acc: 90.8203  loss_bbox: 0.1633  loss_mask: 0.2783
# 07/29 20:23:10 - mmengine - INFO - Epoch(train)  [8][550/731]  lr: 2.0000e-02  eta: 5:04:50  time: 1.1211  data_time: 0.0461  memory: 6381  loss: 0.6702  loss_rpn_cls: 0.0363  loss_rpn_bbox: 0.0650  loss_cls: 0.1308  acc: 93.8477  loss_bbox: 0.1592  loss_mask: 0.2789
# 07/29 20:24:06 - mmengine - INFO - Epoch(train)  [8][600/731]  lr: 2.0000e-02  eta: 5:03:55  time: 1.1326  data_time: 0.0523  memory: 6528  loss: 0.6884  loss_rpn_cls: 0.0393  loss_rpn_bbox: 0.0637  loss_cls: 0.1407  acc: 95.8008  loss_bbox: 0.1665  loss_mask: 0.2781
# 07/29 20:25:02 - mmengine - INFO - Epoch(train)  [8][650/731]  lr: 2.0000e-02  eta: 5:02:59  time: 1.1242  data_time: 0.0480  memory: 6381  loss: 0.6478  loss_rpn_cls: 0.0272  loss_rpn_bbox: 0.0598  loss_cls: 0.1260  acc: 91.8945  loss_bbox: 0.1588  loss_mask: 0.2760
# 07/29 20:25:58 - mmengine - INFO - Epoch(train)  [8][700/731]  lr: 2.0000e-02  eta: 5:02:00  time: 1.1099  data_time: 0.0424  memory: 6382  loss: 0.6238  loss_rpn_cls: 0.0405  loss_rpn_bbox: 0.0608  loss_cls: 0.1152  acc: 95.8008  loss_bbox: 0.1350  loss_mask: 0.2723
# 07/29 20:26:33 - mmengine - INFO - Exp name: custom_config_20230729_183231
# 07/29 20:26:40 - mmengine - INFO - Epoch(val)  [8][ 50/163]    eta: 0:00:16  time: 0.1467  data_time: 0.0028  memory: 6538
# 07/29 20:26:47 - mmengine - INFO - Epoch(val)  [8][100/163]    eta: 0:00:09  time: 0.1465  data_time: 0.0022  memory: 1005
# 07/29 20:26:55 - mmengine - INFO - Epoch(val)  [8][150/163]    eta: 0:00:01  time: 0.1448  data_time: 0.0021  memory: 1005
# 07/29 20:26:57 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=2.63s).
# Accumulating evaluation results...
# DONE (t=0.34s).
# ...
#           (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(224, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn2): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(224, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(224, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(448, 448, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=4, bias=False)
#         (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(224, 448, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#         (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#         (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#         (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#         (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(448, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(448, 896, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(896, 896, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (bn2): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(896, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(896, 2240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2240, 2240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=20, bias=False)
#         (bn2): BatchNorm2d(2240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(2240, 2240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(896, 2240, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://regnetx_12gf'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(224, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(448, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2240, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0-3): 4 x ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): RPNHead(
#     (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_bbox): L1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): StandardRoIHead(
#     (bbox_roi_extractor): SingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#       )
#     )
#     (bbox_head): Shared2FCBBoxHead(
#       (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#       (loss_bbox): L1Loss()
#       (fc_cls): Linear(in_features=1024, out_features=3, bias=True)
#       (fc_reg): Linear(in_features=1024, out_features=8, bias=True)
#       (shared_convs): ModuleList()
#       (shared_fcs): ModuleList(
#         (0): Linear(in_features=12544, out_features=1024, bias=True)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (cls_convs): ModuleList()
#       (cls_fcs): ModuleList()
#       (reg_convs): ModuleList()
#       (reg_fcs): ModuleList()
#       (relu): ReLU(inplace=True)
#     )
#     init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#     (mask_roi_extractor): SingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (1): RoIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (2): RoIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (3): RoIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#       )
#     )
#     (mask_head): FCNMaskHead(
#       (loss_mask): CrossEntropyLoss(avg_non_ignore=False)
#       (convs): ModuleList(
#         (0-3): 4 x ConvModule(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (upsample): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (conv_logits): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU(inplace=True)
#     )
#   )
# )
